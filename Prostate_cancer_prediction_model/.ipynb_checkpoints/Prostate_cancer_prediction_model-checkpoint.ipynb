# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Import and check the Dataset

# %%
# Read data

data = pd.read_csv('./Prostate_Cancer.csv')

# %%
data.head()
# Out:
#    id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   1                M      23       12        151   954       0.143
# 1   2                B       9       13        133  1326       0.143
# 2   3                M      21       27        130  1203       0.125
# 3   4                M      14       16         78   386       0.070
# 4   5                M       9       19        135  1297       0.141
#
#    compactness  symmetry  fractal_dimension
# 0        0.278     0.242              0.079
# 1        0.079     0.181              0.057
# 2        0.160     0.207              0.060
# 3        0.284     0.260              0.097
# 4        0.133     0.181              0.059

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    int64
#  1   diagnosis_result   100 non-null    object
#  2   radius             100 non-null    int64
#  3   texture            100 non-null    int64
#  4   perimeter          100 non-null    int64
#  5   area               100 non-null    int64
#  6   smoothness         100 non-null    float64
#  7   compactness        100 non-null    float64
#  8   symmetry           100 non-null    float64
#  9   fractal_dimension  100 non-null    float64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# There is no missing data.

# %%
data.describe()
# Out:
#                id      radius     texture   perimeter         area  \
# count  100.000000  100.000000  100.000000  100.000000   100.000000
# mean    50.500000   16.850000   18.230000   96.780000   702.880000
# std     29.011492    4.879094    5.192954   23.676089   319.710895
# min      1.000000    9.000000   11.000000   52.000000   202.000000
# 25%     25.750000   12.000000   14.000000   82.500000   476.750000
# 50%     50.500000   17.000000   17.500000   94.000000   644.000000
# 75%     75.250000   21.000000   22.250000  114.250000   917.000000
# max    100.000000   25.000000   27.000000  172.000000  1878.000000
#
#        smoothness  compactness    symmetry  fractal_dimension
# count  100.000000   100.000000  100.000000         100.000000
# mean     0.102730     0.126700    0.193170           0.064690
# std      0.014642     0.061144    0.030785           0.008151
# min      0.070000     0.038000    0.135000           0.053000
# 25%      0.093500     0.080500    0.172000           0.059000
# 50%      0.102000     0.118500    0.190000           0.063000
# 75%      0.112000     0.157000    0.209000           0.069000
# max      0.143000     0.345000    0.304000           0.097000

# %% [markdown]
# The id column can be eliminated. This column adds no value to the data.

# %%
data = data.drop(['id'], axis=1)

# %%
data_dr = data['diagnosis_result'].value_counts()

label = [data_dr.index.tolist()]
plt.pie(data_dr, labels=label[0], shadow=True, explode=(0.0, 0.2), autopct='%1.1f%%', startangle=90)
plt.gcf().set_size_inches(12,6)
plt.show()

# %% [markdown]
# The majority number of cases is found to be maligne. This variable can be set to 0 for maligne and 1 for benigne.

# %%
data['diagnosis_result'].replace({'M':0,'B':1},inplace=True)

# %%
# Data correlation matrix
corr_metrics = data.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row0_col8 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col0 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col2 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col3 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col5 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col6 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col7 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row1_col8 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col0 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col1 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col5 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col6 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col7 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row2_col8 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col4 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col5 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col6 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col7 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row3_col8 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col3 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col5 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col6 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col7 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col0 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col2 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col3 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col4 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col6 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col7 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row5_col8 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row6_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row6_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row6_col2 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row6_col3 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row6_col4 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_bb469600_a6c3_11ec_9bc3_27efe893e949row6_col5 {
#             background-color:  #5a9ec9;
#             color:  #000000;

# %% [markdown]
# Fractal dimension and texture present a low correlation with the remaining variables. Therefore we can eliminate them from our DB. Additional, because perimeter and area have a strong correlation, it will be elimintated to avoid redudancy.

# %%
data = data.drop(['fractal_dimension', 'texture', 'perimeter'], axis=1)

# %% [markdown]
# 2. Train & test sets

# %%
# split the data in train and test function

from sklearn.model_selection import train_test_split

X = data.drop(['diagnosis_result'], axis=1) # Features
y = data['diagnosis_result'] # Labels

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=10)

# %% [markdown]
# 3. ML models

# %%
# Logistic Regression model

from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_log = logreg.predict(X_test)

# %%
# Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators = 50)
forest.fit(X_train,y_train)
pred_forest = forest.predict(X_test)

# %%
# KNeighbors Classifier

from sklearn.neighbors import KNeighborsClassifier

kn = KNeighborsClassifier(n_neighbors=2)
kn.fit(X_train,y_train)
pred_kn = kn.predict(X_test)

# %%
# Decision Tree Classifier

from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()
tree.fit(X_train,y_train)
pred_tree = tree.predict(X_test)

# %%
from sklearn.metrics import classification_report

class_rep_log = classification_report(y_test, pred_log)
class_rep_forest = classification_report(y_test, pred_forest)
class_rep_kn = classification_report(y_test, pred_kn)
class_rep_tree = classification_report(y_test, pred_tree)

print("Logistic Regression: \n", class_rep_log)
print("Forest Classifier: \n", class_rep_forest)
print("KNeighbors Classifier: \n", class_rep_kn)
print("Decision Tree: \n", class_rep_tree)
# Out:
# Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.75      0.82      0.78        11
#
#     accuracy                           0.75        20
#    macro avg       0.75      0.74      0.74        20
# weighted avg       0.75      0.75      0.75        20
#
# Forest Classifier:
#                precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89         9
#            1       0.91      0.91      0.91        11
#
#     accuracy                           0.90        20
#    macro avg       0.90      0.90      0.90        20
# weighted avg       0.90      0.90      0.90        20
#
# KNeighbors Classifier:
#                precision    recall  f1-score   support
#
#            0       0.54      0.78      0.64         9
#            1       0.71      0.45      0.56        11
#
#     accuracy                           0.60        20
#    macro avg       0.63      0.62      0.60        20
# weighted avg       0.64      0.60      0.59        20
#
# Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78         9
#            1       0.82      0.82      0.82        11
#
#     accuracy                           0.80        20
#    macro avg       0.80      0.80      0.80        20
# weighted avg       0.80      0.80      0.80        20

# %% [markdown]
# The Forest Classificatio model has the highest average precision of 0.9, and both variables are well balanced (benigne: 1 and maligne: 0).
#
# The Decision Tree model has also a good average precision. However in this model the maligne results are better classified.

# %%
from sklearn.model_selection import KFold, cross_val_score

kf = KFold(10)

logit_score = cross_val_score(logreg, X, y, cv=kf)
forest_score = cross_val_score(forest, X, y, cv=kf)
KNeighbors_score = cross_val_score(kn, X, y, cv=kf)
tree_score = cross_val_score(tree, X, y, cv=kf)


# Print the mean of each array of scores
print("Logistic Regression:", np.mean(logit_score), '\n'
      "Forest Classification:", np.mean(forest_score), '\n'
      "KNeighbors Classification:", np.mean(KNeighbors_score), '\n'
      "Decision Tree:", np.mean(tree_score), '\n'
     )
# Out:
# Logistic Regression: 0.8
# Forest Classification: 0.8600000000000001
# KNeighbors Classification: 0.7100000000000001
# Decision Tree: 0.8400000000000001

# %% [markdown]
# The highest score is obtained with the Forest Classification, followed by the Decision tree.
